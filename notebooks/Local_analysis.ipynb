# %%
# !python run_local.py --yaml LP_283.yaml -N 1000
# Out:
# No display detected: using non-interactive 'Agg' backend.
# ######## Doing folder: /Users/aimematheron/Dropbox/AimeDF/yamls
# ######## Doing file: /Users/aimematheron/Dropbox/AimeDF/yamls/LP_283.yaml
# Not moving yaml file.
# #### Doing the simulation type 0: dark-field, N=1000
# sorting
# start (elem.n.0)   ###
# skipping zero propagation
# beam_shaper (elem.n.1)   ###
# flow_000_-1.20 (elem.n.2)   ###
# Saving figure: flow_000_-1.20
# flow_001_-1.19 (elem.n.3)   ###
# Saving figure: flow_001_-1.19
# flow_002_-1.18 (elem.n.4)   ###
# Saving figure: flow_002_-1.18
# flow_003_-1.17 (elem.n.5)   ###
# Saving figure: flow_003_-1.17
# flow_004_-1.16 (elem.n.6)   ###
# Saving figure: flow_004_-1.16
# flow_005_-1.15 (elem.n.7)   ###
# Saving figure: flow_005_-1.15
# O1 (elem.n.8)   ###
# flow_006_-1.14 (elem.n.9)   ###
# Saving figure: flow_006_-1.14
# flow_007_-1.13 (elem.n.10)   ###
# Saving figure: flow_007_-1.13
# flow_008_-1.12 (elem.n.11)   ###
# Saving figure: flow_008_-1.12
# ...

# %%
# !python run_local.py
# Out:
# /Users/aime/envs/darkfield_env/bin/python: can't open file '/Users/aime/Library/CloudStorage/Dropbox/QED_at_jena/Backup_codes/Environnement_DF_20Juin/darkfield_p5438/notebooks/run_local.py': [Errno 2] No such file or directory
