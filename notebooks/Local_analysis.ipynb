# %%
# !python run_local.py --yaml LP_283.yaml -N 1000
# Out:
# Traceback (most recent call last):
#   File "/Users/aimematheron/Dropbox/AimeDF/src/darkfield/dfdf_Aime.py", line 11, in <module>
#     import matplotlib
#   File "/Users/aimematheron/Dropbox/AimeDF/darkfield_env/lib/python3.9/site-packages/matplotlib/__init__.py", line 1273, in <module>
#     rcParams['backend'] = os.environ.get('MPLBACKEND')
#   File "/Users/aimematheron/Dropbox/AimeDF/darkfield_env/lib/python3.9/site-packages/matplotlib/__init__.py", line 741, in __setitem__
#     raise ValueError(f"Key {key}: {ve}") from None
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
# !python run_local.py
# Out:
# /Users/aime/envs/darkfield_env/bin/python: can't open file '/Users/aime/Library/CloudStorage/Dropbox/QED_at_jena/Backup_codes/Environnement_DF_20Juin/darkfield_p5438/notebooks/run_local.py': [Errno 2] No such file or directory
