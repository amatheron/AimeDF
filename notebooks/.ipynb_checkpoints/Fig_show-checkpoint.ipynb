# %%
import os
import sys
import time
import random
import yaml
import warnings

import darkfield
from darkfield import mmmUtils as mu
from darkfield import rossendorfer_farbenliste as rofl
from darkfield import diffra as df

import numpy as np
from bash_config import write_bash
from darkfield.A14_mod import HOME 

from LightPipes import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.colors as colors
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from matplotlib.colors import LogNorm
from importlib import reload

# %%
proj='/home/qo38soh/darkfield_p5438/pooyan'
#yaml='5438_N6000'
yaml='5438_1_N6000_23-04-2025_17-37'
#yaml_2='5438_2_N5000_16-04-2025_16:17'

# %%
pwd!
# Out:
# '/home/qo38soh/darkfield_p5438/notebooks'

# %%
fn=os.path.join(proj,'pickles',yaml+'_figs.pickle')
print(fn)
figs=mu.loadPickle(fn)
print(list(figs.keys()))
# Out:
# /home/qo38soh/darkfield_p5438/pooyan/pickles/5438_1_N6000_23-04-2025_17-13_figs.pickle
# ['CRL1', 'PH', 'TCC', 'A1-', 'A1', 'Det']

# %%
fn_2=os.path.join(proj,'pickles',yaml_2+'_figs.pickle')
print(fn_2)
figs_2=mu.loadPickle(fn_2)
print(list(figs_2.keys()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fn_2=os.path.join(proj,'pickles',yaml_2+'_figs.pickle')
#       2 print(fn_2)
#       3 figs_2=mu.loadPickle(fn_2)
#
# NameError: name 'yaml_2' is not defined

# %%
ps = 2723e-6

# %%
for fig in figs.keys():
    if fig!='A1': continue
    print(fig)
    mu.figure()
    img=figs[fig][0]
    ps2=figs[fig][2]*1e6/2
    ex=(-ps2,ps2,-ps2,ps2)
    plt.imshow(img,cmap=rofl.cmap())#, norm=LogNorm())#,extent=ex)#, norm=LogNorm()) [135:165,135:165]
    L,H = img.shape
    side = 15
    rect_dim = [L//2-side, L//2+side, H//2-side, H//2+side]
    rect_2 = [1,160,110,130]
    #mu.drawRect(rect_dim)
    #mu.drawRect(rect_2)
    plt.title(yaml+'   '+ fig)
    plt.colorbar()
    ps3=ps2
    #mu.savefig(os.path.join(proj,'images',yaml+f'_{fig}.png'))
    #plt.clim(0.2,0.35)
    plt.show()
    print("{:.1e}".format(np.sum(img)*ps**2))
# Out:
# A1
# 4.5e-04

# %%
img.shape
# Out:
# (300, 300)

# %%
a = np.sum(img[110:130,140:160])

# %%
a
# Out:
# np.float32(0.15872705)

# %%
for fig in figs.keys():
    if fig!='TCC': continue
    print(fig)
    mu.figure()
    img_1=figs[fig][0]
    ps2=figs[fig][2]*1e6/2
    ex=(-ps2,ps2,-ps2,ps2)
    plt.imshow(img_1,cmap=rofl.cmap(), norm=LogNorm())#,extent=ex)#, norm=LogNorm())
    L,H = img_1.shape
    side = 10
    rect_dim = [L//2-side, L//2+side, H//2-side, H//2+side]
    mu.drawRect(rect_dim)
    plt.title(yaml+'   '+ fig)
    plt.colorbar()
    ps3=ps2
    #mu.savefig(os.path.join(proj,'images',yaml+f'_{fig}.png'))
    plt.clim(0.01,0.35)
    plt.show()
    print("{:.1e}".format(np.sum(img_1)))
# Out:
# TCC
# 5.7e+01

# %%
np.argwhere(img_1==img_1.max())
# Out:
# array([[150, 150]])

# %%
a/np.sum(img_1)
# Out:
# np.float32(0.3010354)

# %%
plt.plot(img[:,150])
#plt.yscale('log')

# %%
prof=np.nansum(img,0)
plt.semilogy(prof)
plt.show()

print(np.sum(img))
# Out:
# 697.72363
