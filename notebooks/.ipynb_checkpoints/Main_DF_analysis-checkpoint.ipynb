# %%
import os
import sys
import darkfield
import numpy as np
from bash_config import write_bash
#from darkfield.diffra_v2 import HOME 
#from darkfield.dfdf_Aime import cluster_path

# %%
################## DEFINING THE BASH PARAMETERS OF THE SIMULATION ################

upd_params = {
    'n_cpus': 24,
    'mem': '600GB',
    'yaml': 'Airscat1.yaml'
} #previously n_cpus=24, mem=650
path = os.path.join('/home/yu79deg/darkfield_p5438/bash')
bash_path = write_bash(path, 400, upd_params)

# %%
#################### LAUNCHING THE SIMULATION #################
os.system(f"sbatch {bash_path}")
# Out:
# Submitted batch job 3935079
# 0

# %%
#################### VISUALIZING THE QUEUE #################
# !squeue --me
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            3928266   hij-gpu jupyterl  yu79deg  R 1-01:05:33      1 gpu001

# %%
# !scancel 3921885

# %%
##################### FLOW PLOT OF SIMULATIONS ####################
###################################################################

#from darkfield.diffra_v2 import flow_plot
import importlib
import darkfield.diffra_v2
importlib.reload(darkfield.diffra_v2)
from darkfield.diffra_v2 import flow_plot

#%matplotlib widget

#Going back to the root folder :
# %cd /home/yu79deg 

project_dir = "darkfield_p5438/Aime"
#project_dir="/home/yu79deg/darkfield_p5438/Aime"

file = "LP_308" #name of the file
#file = "Matt_2" #name of the file
file = "Alt_1" #name of the file

############# PLOTTING PARAMETERS ############
cl = [1e-11, 50] #Color scale (min, max) for the pcolor()
gyax_def = [-1000, 1000, 0.1] #vertical axis (start, end, stepsize) (in [um])
vertical_type = 'center' #(center, integral, vert-integral)
log = 1 #log or linear scale (LINEAR SCALE DOESNT WORK)
xl = [-15,15] #horizontal axis limits
xl = None #horizontal axis limits
flow_plot_crange = 1e-5 #relative scale to plot images.

#==================================================#
flow_figs = 0 #save the flow figs (Pretty long to run!)
create_video_ff = 0 #create a video from the saved pictures
#==================================================#

# Call the function
flow_plot(project_dir, file, cl=cl, gyax_def=gyax_def,
          vertical_type=vertical_type, log=log, xl=xl,
          flow_figs=flow_figs, flow_plot_crange=flow_plot_crange)



if create_video_ff and flow_figs:
    image_dir = f"darkfield_p5438/Aime/flow_figs/{file}"
    output_file = "movie.mp4"
    framerate = 10
    video_images_path = ""
    input_pattern = f"{image_dir}/ff_%04d.png"
    # !ffmpeg -framerate {framerate} -i "{input_pattern}" -c:v libx264 -pix_fmt yuv420p "{image_dir}/{output_file}"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 7
#       5 import importlib
#       6 import darkfield.diffra_v2
# ----> 7 importlib.reload(darkfield.diffra_v2)
#       8 from darkfield.diffra_v2 import flow_plot
#      10 #%matplotlib widget
#      11
#      12 #Going back to the root folder :
#
# File ~/micromamba/envs/darkfield/lib/python3.12/importlib/__init__.py:131, in reload(module)
#     129 if spec is None:
#     130     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 131 _bootstrap._exec(spec, module)
#     132 # The module may have replaced itself in sys.modules!
#     133 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:866, in _exec(spec, module)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/darkfield_p5438/src/darkfield/diffra_v2.py:14
#      10 from scipy import signal
#      12 from pathlib import Path
# ---> 14 from skimage.transform import resize
#      15 from scipy.signal import fftconvolve
#      17 #import darkfield.regularized_propagation as rp
#
# ModuleNotFoundError: No module named 'skimage'

# %%
######################### GENERATE YAML FILES FOR SCANS ###############

# !python /home/yu79deg/darkfield_p5438/yamls/yaml_2Dscan_TCSlit_Div.py
# Out:
# Written LP_327.yaml (TCSlit_size=0, wide_factor=0.4)
# Written LP_328.yaml (TCSlit_size=0, wide_factor=0.5)
# Written LP_329.yaml (TCSlit_size=0, wide_factor=0.6)
# Written LP_330.yaml (TCSlit_size=0, wide_factor=0.7)
# Written LP_331.yaml (TCSlit_size=0, wide_factor=0.8)
# Written LP_332.yaml (TCSlit_size=0, wide_factor=0.9)
# Written LP_333.yaml (TCSlit_size=0, wide_factor=1)
# Written LP_334.yaml (TCSlit_size=0, wide_factor=1.2)
# Written LP_335.yaml (TCSlit_size=0, wide_factor=1.4)
# Written LP_336.yaml (TCSlit_size=2, wide_factor=0.4)
# Written LP_337.yaml (TCSlit_size=2, wide_factor=0.5)
# Written LP_338.yaml (TCSlit_size=2, wide_factor=0.6)
# Written LP_339.yaml (TCSlit_size=2, wide_factor=0.7)
# Written LP_340.yaml (TCSlit_size=2, wide_factor=0.8)
# Written LP_341.yaml (TCSlit_size=2, wide_factor=0.9)
# Written LP_342.yaml (TCSlit_size=2, wide_factor=1)
# Written LP_343.yaml (TCSlit_size=2, wide_factor=1.2)
# Written LP_344.yaml (TCSlit_size=2, wide_factor=1.4)
# Written LP_345.yaml (TCSlit_size=5, wide_factor=0.4)
# Written LP_346.yaml (TCSlit_size=5, wide_factor=0.5)
# Written LP_347.yaml (TCSlit_size=5, wide_factor=0.6)
# Written LP_348.yaml (TCSlit_size=5, wide_factor=0.7)
# Written LP_349.yaml (TCSlit_size=5, wide_factor=0.8)
# Written LP_350.yaml (TCSlit_size=5, wide_factor=0.9)
# Written LP_351.yaml (TCSlit_size=5, wide_factor=1)
# Written LP_352.yaml (TCSlit_size=5, wide_factor=1.2)
# Written LP_353.yaml (TCSlit_size=5, wide_factor=1.4)
# Written LP_354.yaml (TCSlit_size=10, wide_factor=0.4)
# Written LP_355.yaml (TCSlit_size=10, wide_factor=0.5)
# Written LP_356.yaml (TCSlit_size=10, wide_factor=0.6)
# Written LP_357.yaml (TCSlit_size=10, wide_factor=0.7)
# Written LP_358.yaml (TCSlit_size=10, wide_factor=0.8)
# Written LP_359.yaml (TCSlit_size=10, wide_factor=0.9)
# Written LP_360.yaml (TCSlit_size=10, wide_factor=1)
# Written LP_361.yaml (TCSlit_size=10, wide_factor=1.2)
# Written LP_362.yaml (TCSlit_size=10, wide_factor=1.4)
# Written LP_363.yaml (TCSlit_size=15, wide_factor=0.4)
# Written LP_364.yaml (TCSlit_size=15, wide_factor=0.5)
# Written LP_365.yaml (TCSlit_size=15, wide_factor=0.6)
# Written LP_366.yaml (TCSlit_size=15, wide_factor=0.7)
# Written LP_367.yaml (TCSlit_size=15, wide_factor=0.8)
# Written LP_368.yaml (TCSlit_size=15, wide_factor=0.9)
# Written LP_369.yaml (TCSlit_size=15, wide_factor=1)
# Written LP_370.yaml (TCSlit_size=15, wide_factor=1.2)
# Written LP_371.yaml (TCSlit_size=15, wide_factor=1.4)
# Written LP_372.yaml (TCSlit_size=20, wide_factor=0.4)
# Written LP_373.yaml (TCSlit_size=20, wide_factor=0.5)
# Written LP_374.yaml (TCSlit_size=20, wide_factor=0.6)
# Written LP_375.yaml (TCSlit_size=20, wide_factor=0.7)
# Written LP_376.yaml (TCSlit_size=20, wide_factor=0.8)
# Written LP_377.yaml (TCSlit_size=20, wide_factor=0.9)
# Written LP_378.yaml (TCSlit_size=20, wide_factor=1)
# Written LP_379.yaml (TCSlit_size=20, wide_factor=1.2)
# Written LP_380.yaml (TCSlit_size=20, wide_factor=1.4)
# Written LP_381.yaml (TCSlit_size=30, wide_factor=0.4)
# Written LP_382.yaml (TCSlit_size=30, wide_factor=0.5)
# Written LP_383.yaml (TCSlit_size=30, wide_factor=0.6)
# Written LP_384.yaml (TCSlit_size=30, wide_factor=0.7)
# Written LP_385.yaml (TCSlit_size=30, wide_factor=0.8)
# Written LP_386.yaml (TCSlit_size=30, wide_factor=0.9)
# Written LP_387.yaml (TCSlit_size=30, wide_factor=1)
# Written LP_388.yaml (TCSlit_size=30, wide_factor=1.2)
# Written LP_389.yaml (TCSlit_size=30, wide_factor=1.4)
# Written LP_390.yaml (TCSlit_size=40, wide_factor=0.4)
# Written LP_391.yaml (TCSlit_size=40, wide_factor=0.5)
# Written LP_392.yaml (TCSlit_size=40, wide_factor=0.6)
# Written LP_393.yaml (TCSlit_size=40, wide_factor=0.7)
# Written LP_394.yaml (TCSlit_size=40, wide_factor=0.8)
# Written LP_395.yaml (TCSlit_size=40, wide_factor=0.9)
# Written LP_396.yaml (TCSlit_size=40, wide_factor=1)
# Written LP_397.yaml (TCSlit_size=40, wide_factor=1.2)
# Written LP_398.yaml (TCSlit_size=40, wide_factor=1.4)
# Written LP_399.yaml (TCSlit_size=50, wide_factor=0.4)
# Written LP_400.yaml (TCSlit_size=50, wide_factor=0.5)
# Written LP_401.yaml (TCSlit_size=50, wide_factor=0.6)
# Written LP_402.yaml (TCSlit_size=50, wide_factor=0.7)
# Written LP_403.yaml (TCSlit_size=50, wide_factor=0.8)
# Written LP_404.yaml (TCSlit_size=50, wide_factor=0.9)
# Written LP_405.yaml (TCSlit_size=50, wide_factor=1)
# Written LP_406.yaml (TCSlit_size=50, wide_factor=1.2)
# Written LP_407.yaml (TCSlit_size=50, wide_factor=1.4)

# %%
######################## RUN ALL THE SIMULATIONS ###################

def get_simulation_list(manual_list=None, start=None, end=None):
    if manual_list:
        return manual_list
    elif start is not None and end is not None:
        return [f"LP_{i}" for i in range(start, end + 1)]
    else:
        raise ValueError("Either provide a manual list or a start and end value.")

###################### Option 1: manual list #######################
#sim_names = get_simulation_list(manual_list=["LP_30", "LP_31", "LP_35"])

#################### Option 2: auto-generated list #################
sim_names = get_simulation_list(start=327, end=407)

################### Parameters for SLURM submission ################
upd_params = {
    'n_cpus': 24,
    'mem': '600GB',
}

# Folder for bash scripts
path = os.path.join(HOME, 'bash')

#################### Loop over all simulation names ################
for sim in sim_names:
    upd_params['yaml'] = sim + '.yaml'  # Assign current yaml file
    bash_path = write_bash(path, 6000, upd_params)
    print(f"Submitting {sim} with bash file: {bash_path}")
    os.system(f"sbatch {bash_path}")


# !squeue --me # See that all simulations are indeed running.
# Out:
# Submitting LP_327 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922241
# Submitting LP_328 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922242
# Submitting LP_329 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922243
# Submitting LP_330 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922244
# Submitting LP_331 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922245
# Submitting LP_332 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922246
# Submitting LP_333 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922247
# Submitting LP_334 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922248
# Submitting LP_335 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922249
# Submitting LP_336 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922250
# Submitting LP_337 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922251
# Submitting LP_338 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922252
# Submitting LP_339 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922253
# Submitting LP_340 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922254
# Submitting LP_341 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922255
# Submitting LP_342 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922256
# Submitting LP_343 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922257
# Submitting LP_344 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922258
# Submitting LP_345 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922259
# Submitting LP_346 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922260
# Submitting LP_347 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922261
# Submitting LP_348 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922262
# Submitting LP_349 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922263
# Submitting LP_350 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922264
# Submitting LP_351 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922265
# Submitting LP_352 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922266
# Submitting LP_353 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922267
# Submitting LP_354 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922268
# Submitting LP_355 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922269
# Submitting LP_356 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922270
# Submitting LP_357 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922271
# Submitting LP_358 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922272
# Submitting LP_359 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922273
# Submitting LP_360 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922274
# Submitting LP_361 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922275
# Submitting LP_362 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922276
# Submitting LP_363 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922277
# Submitting LP_364 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922278
# Submitting LP_365 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922279
# Submitting LP_366 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922280
# Submitting LP_367 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922281
# Submitting LP_368 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922282
# Submitting LP_369 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922283
# Submitting LP_370 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922284
# Submitting LP_371 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922285
# Submitting LP_372 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922286
# Submitting LP_373 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922287
# Submitting LP_374 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922288
# Submitting LP_375 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922289
# Submitting LP_376 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922290
# Submitting LP_377 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922291
# Submitting LP_378 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922292
# Submitting LP_379 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922293
# Submitting LP_380 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922294
# Submitting LP_381 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922295
# Submitting LP_382 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922296
# Submitting LP_383 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922297
# Submitting LP_384 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922298
# Submitting LP_385 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922299
# Submitting LP_386 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922300
# Submitting LP_387 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922301
# Submitting LP_388 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922302
# Submitting LP_389 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922303
# Submitting LP_390 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922304
# Submitting LP_391 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922305
# Submitting LP_392 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922306
# Submitting LP_393 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922307
# Submitting LP_394 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922308
# Submitting LP_395 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922309
# Submitting LP_396 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922310
# Submitting LP_397 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922311
# Submitting LP_398 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922312
# Submitting LP_399 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922313
# Submitting LP_400 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922314
# Submitting LP_401 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922315
# Submitting LP_402 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922316
# Submitting LP_403 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922317
# Submitting LP_404 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922318
# Submitting LP_405 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922319
# Submitting LP_406 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922320
# Submitting LP_407 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3922321
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            
#            3922309   hij-gpu   LP_395  yu79deg PD       0:00      1 (Priority)
#            3922310   hij-gpu   LP_396  yu79deg PD       0:00      1 (Priority)
#            3922311   hij-gpu   LP_397  yu79deg PD       0:00      1 (Priority)
#            3922312   hij-gpu   LP_398  yu79deg PD       0:00      1 (Priority)
#            3922313   hij-gpu   LP_399  yu79deg PD       0:00      1 (Priority)
#            3922314   hij-gpu   LP_400  yu79deg PD       0:00      1 (Priority)
#            3922315   hij-gpu   LP_401  yu79deg PD       0:00      1 (Priority)
#            3922316   hij-gpu   LP_402  yu79deg PD       0:00      1 (Priority)
#            3922317   hij-gpu   LP_403  yu79deg PD       0:00      1 (Priority)
#            3922318   hij-gpu   LP_404  yu79deg PD       0:00      1 (Priority)
#            3922319   hij-gpu   LP_405  yu79deg PD       0:00      1 (Priority)
#            3922320   hij-gpu   LP_406  yu79deg PD       0:00      1 (Priority)
#            3922321   hij-gpu   LP_407  yu79deg PD       0:00      1 (Priority)
#            3895923   hij-gpu jupyterl  yu79deg  R 3-06:10:18      1 gpu001
#            3922222   hij-gpu   LP_311  yu79deg  R      16:10      1 gpu002
#            3922223   hij-gpu   LP_312  yu79deg  R      16:10      1 gpu003
#            3922224   hij-gpu   LP_313  yu79deg  R      16:10      1 gpu004

# %%
# !squeue --me # See that all simulations are indeed running.

# %%
#################### EXTRACT SHADOW FACTOR FROM SIMULATION ###################
import darkfield.mmmUtils_v2 as mu

project_dir = '/home/yu79deg/darkfield_p5438/Aime'
yaml_tag = 'LP_124'  # Simulation name


pickle_file = os.path.join(project_dir, 'pickles', f'{yaml_tag}_res.pickle')
print(f"Loading: {pickle_file}")


res = mu.loadPickle(pickle_file) #loading the general parameters
params=res[1]

SF_13 = params['intensities']['roi'] / params['intensities']['TCC']
SF_75 = params['intensities']['roi2'] / params['intensities']['TCC']

print(SF_13,SF_75)

# %%
################## PLOT THE EVOLUTION OF SHADOW FACTOR AS A FUNCTION OF A GIVEN SCANNED PARAMETER ###############

import os
import yaml
import numpy as np
import matplotlib.pyplot as plt
import darkfield.mmmUtils_v2 as mu  # This must be available in your environment

# %matplotlib widget

# Setup paths
project_dir = '/home/yu79deg/darkfield_p5438/Aime'
yaml_dir = '/home/yu79deg/darkfield_p5438/yamls'
pickle_dir = os.path.join(project_dir, 'pickles')

# List of simulations (numbers only)
simulation_ids = np.arange(300,307)
simulations = [f'LP_{i}' for i in simulation_ids]

# Parameter config
ph_key = 'PH'          # The element key in YAML
scan_param_name = 'size'        # Parameter to scan
xaxis_label = 'PH size [µm]'  # Label for plot

# Data lists
scanned_values = []
sf_13_list = []
sf_75_list = []

# Loop through simulations
for sim in simulations:
    print(f"\nProcessing simulation: {sim}")

    # --- Load pickle file ---
    pickle_file = os.path.join(pickle_dir, f'{sim}_res.pickle')
    if not os.path.isfile(pickle_file):
        print(f"⚠️ Missing pickle file: {pickle_file}")
        continue

    res = mu.loadPickle(pickle_file)
    params = res[1]

    try:
        sf_13 = params['intensities']['roi'] / params['intensities']['TCC']
        sf_75 = params['intensities']['roi2'] / params['intensities']['TCC']
    except KeyError:
        print(f"⚠️ Missing intensity data in: {sim}")
        continue

    # --- Load YAML file ---
    yaml_file = os.path.join(yaml_dir, f'{sim}.yaml')
    if not os.path.isfile(yaml_file):
        print(f"⚠️ Missing YAML file: {yaml_file}")
        continue

    with open(yaml_file, 'r') as f:
        yaml_data = yaml.safe_load(f)

    # --- Extract parameter ---
    try:
        element = yaml_data[ph_key]
        if 'in' in element and element['in'] == 0:
            scan_value = 0.0
        else:
            scan_value = element[scan_param_name]
    except KeyError:
        print(f"⚠️ Parameter '{scan_param_name}' not found in element '{ph_key}' for {sim}")
        continue

    # Store data (convert to µm)
    scanned_values.append(scan_value * 1e6)
    sf_13_list.append(sf_13)
    sf_75_list.append(sf_75)

# --- Plotting ---
plt.figure(figsize=(5, 5))
plt.plot(scanned_values, sf_13_list, 'o-', label='SF_13')
plt.plot(scanned_values, sf_75_list, 's-', label='SF_75')
plt. yscale("log")
plt.xlabel(xaxis_label)
plt.ylabel("Shadow factor")
plt.title(f"Shadow factor vs {xaxis_label}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
##################### LOOP OF FLOW PLOT OF SIMULATIONS ####################
###################################################################

import importlib
import darkfield.diffra_v2
importlib.reload(darkfield.diffra_v2)
from darkfield.diffra_v2 import flow_plot

import os

# Set working directory
os.chdir("/home/yu79deg")

project_dir = "darkfield_p5438/Aime"

############# LOOP CONTROL ############
LP_start = 278
LP_end = 286  # inclusive
#######################################

############# PLOTTING PARAMETERS ############
cl = [1e-11, 50]                      # Color scale (min, max) for pcolor()
gyax_def = [-600, 600, 0.1]         # vertical axis [start, end, stepsize] in µm
vertical_type = 'center'             # ('center', 'integral', 'vert-integral')
log = 1                              # log scale (linear doesn't work)
xl = None                            # horizontal axis limits (None = auto)
flow_plot_crange = 1e-5              # relative scale for plotting images
flow_figs = 0                        # save flow figs (0 = don't, 1 = yes)
create_video_ff = 0                  # make video from flow figs (requires ffmpeg)

# ========== LOOP THROUGH SIMULATIONS ========== #
for LP_num in range(LP_start, LP_end + 1):
    file = f"LP_{LP_num}"
    print(f"\n========== Processing {file} ==========\n")

    try:
        flow_plot(project_dir, file, cl=cl, gyax_def=gyax_def,
                  vertical_type=vertical_type, log=log, xl=xl,
                  flow_figs=flow_figs, flow_plot_crange=flow_plot_crange)
    except Exception as e:
        print(f"⚠️ Error processing {file}: {e}")
        continue

    # Create video from saved figures
    if create_video_ff and flow_figs:
        image_dir = os.path.join(project_dir, "flow_figs", file)
        output_file = os.path.join(image_dir, "movie.mp4")
        input_pattern = os.path.join(image_dir, "ff_%04d.png")

        cmd = f"ffmpeg -framerate 10 -i {input_pattern} -c:v libx264 -pix_fmt yuv420p {output_file}"
        print(f"Creating video: {output_file}")
        os.system(cmd)

# %%
# !python /home/yu79deg/darkfield_p5438/notebooks/CRL_calculator/crl_calculator_6.py
