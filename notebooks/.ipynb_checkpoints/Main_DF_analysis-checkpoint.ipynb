# %%
import os
import sys
import darkfield
import numpy as np
from bash_config import write_bash
from darkfield.diffra_v2 import HOME

# %%
################## DEFINING THE BASH PARAMETERS OF THE SIMULATION ################

upd_params = {
    'n_cpus': 24,
    'mem': '600GB',
    'yaml': 'Matt_2.yaml'
} #previously n_cpus=24, mem=650
path = os.path.join(HOME,'bash')
bash_path = write_bash(path, 6000, upd_params)
print(bash_path)
# Out:
# /home/yu79deg/darkfield_p5438/bash/job.slurm

# %%
#################### LAUNCHING THE SIMULATION #################
os.system(f"sbatch {bash_path}")
# Out:
# Submitted batch job 3859583
# 0

# %%
#################### VISUALIZING THE QUEUE #################
# !squeue --me
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            3846796   hij-gpu jupyterl  yu79deg  R 2-06:32:23      1 gpu004
#            3859583   hij-gpu   Matt_2  yu79deg  R       0:01      1 gpu004

# %%
# !scancel 3858279

# %%
##################### FLOW PLOT OF SIMULATIONS ####################
###################################################################

#from darkfield.diffra_v2 import flow_plot
import importlib
import darkfield.diffra_v2
importlib.reload(darkfield.diffra_v2)
from darkfield.diffra_v2 import flow_plot

#%matplotlib widget

#Going back to the root folder :
# %cd /home/yu79deg 

project_dir = "darkfield_p5438/Aime"

file = "LP_166" #name of the file
#file = "Matt_1" #name of the file

############# PLOTTING PARAMETERS ############
cl = [1e-11, 50] #Color scale (min, max) for the pcolor()
gyax_def = [-1000, 1000, 0.1] #vertical axis (start, end, stepsize) (in [um])
vertical_type = 'center' #(center, integral, vert-integral)
log = 1 #log or linear scale (LINEAR SCALE DOESNT WORK)
xl = [-15,15] #horizontal axis limits
xl = None #horizontal axis limits
flow_plot_crange = 1e-5 #relative scale to plot images.

#==================================================#
flow_figs = 0 #save the flow figs (Pretty long to run!)
create_video_ff = 0 #create a video from the saved pictures
#==================================================#

# Call the function
flow_plot(project_dir, file, cl=cl, gyax_def=gyax_def,
          vertical_type=vertical_type, log=log, xl=xl,
          flow_figs=flow_figs, flow_plot_crange=flow_plot_crange)



if create_video_ff and flow_figs:
    image_dir = f"darkfield_p5438/Aime/flow_figs/{file}"
    output_file = "movie.mp4"
    framerate = 10
    video_images_path = ""
    input_pattern = f"{image_dir}/ff_%04d.png"
    # !ffmpeg -framerate {framerate} -i "{input_pattern}" -c:v libx264 -pix_fmt yuv420p "{image_dir}/{output_file}"
# Out:
# /home/yu79deg
# [1e-11, 50]
#  This is outside (-1.01e+02,-9.50e+02):start
#  This is outside (-1.00e+02,-9.00e+02):beam_shaper
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
######################### GENERATE YAML FILES FOR SCANS ###############

# !python /home/yu79deg/darkfield_p5438/yamls/yaml_scan_DefectLambda.py
# Out:
# Written LP_178.yaml (defect_lambda=50)
# Written LP_179.yaml (defect_lambda=45)
# Written LP_180.yaml (defect_lambda=40)
# Written LP_181.yaml (defect_lambda=35)
# Written LP_182.yaml (defect_lambda=30)
# Written LP_183.yaml (defect_lambda=25)
# Written LP_184.yaml (defect_lambda=20)
# Written LP_185.yaml (defect_lambda=15)
# Written LP_186.yaml (defect_lambda=10)
# Written LP_187.yaml (defect_lambda=5)
# Written LP_188.yaml (defect_lambda=2)

# %%
######################## RUN ALL THE SIMULATIONS ###################

def get_simulation_list(manual_list=None, start=None, end=None):
    if manual_list:
        return manual_list
    elif start is not None and end is not None:
        return [f"LP_{i}" for i in range(start, end + 1)]
    else:
        raise ValueError("Either provide a manual list or a start and end value.")

###################### Option 1: manual list #######################
#sim_names = get_simulation_list(manual_list=["LP_30", "LP_31", "LP_35"])

#################### Option 2: auto-generated list #################
sim_names = get_simulation_list(start=178, end=188)

################### Parameters for SLURM submission ################
upd_params = {
    'n_cpus': 24,
    'mem': '600GB',
}

# Folder for bash scripts
path = os.path.join(HOME, 'bash')

#################### Loop over all simulation names ################
for sim in sim_names:
    upd_params['yaml'] = sim + '.yaml'  # Assign current yaml file
    bash_path = write_bash(path, 1000, upd_params)
    print(f"Submitting {sim} with bash file: {bash_path}")
    os.system(f"sbatch {bash_path}")


# !squeue --me # See that all simulations are indeed running.
# Out:
# Submitting LP_178 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859649
# Submitting LP_179 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859650
# Submitting LP_180 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859651
# Submitting LP_181 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859652
# Submitting LP_182 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859653
# Submitting LP_183 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859654
# Submitting LP_184 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859655
# Submitting LP_185 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859656
# Submitting LP_186 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859657
# Submitting LP_187 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859658
# Submitting LP_188 with bash file: /home/yu79deg/darkfield_p5438/bash/job.slurm
# Submitted batch job 3859659
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            3859641   hij-gpu   LP_174  yu79deg PD       0:00      1 (Resources)
#            3859642   hij-gpu   LP_175  yu79deg PD       0:00      1 (Priority)
#            3859643   hij-gpu   LP_176  yu79deg PD       0:00      1 (Priority)
#            3859649   hij-gpu   LP_178  yu79deg PD       0:00      1 (Priority)
#            3859650   hij-gpu   LP_179  yu79deg PD       0:00      1 (Priority)
#            3859651   hij-gpu   LP_180  yu79deg PD       0:00      1 (Priority)
#            3859652   hij-gpu   LP_181  yu79deg PD       0:00      1 (Priority)
#            3859653   hij-gpu   LP_182  yu79deg PD       0:00      1 (Priority)
#            3859654   hij-gpu   LP_183  yu79deg PD       0:00      1 (Priority)
#            3859655   hij-gpu   LP_184  yu79deg PD       0:00      1 (Priority)
#            3859656   hij-gpu   LP_185  yu79deg PD       0:00      1 (Priority)
#            3859657   hij-gpu   LP_186  yu79deg PD       0:00      1 (Priority)
#            3859658   hij-gpu   LP_187  yu79deg PD       0:00      1 (Priority)
#            3859659   hij-gpu   LP_188  yu79deg PD       0:00      1 (Priority)
#            3846796   hij-gpu jupyterl  yu79deg  R 2-06:45:42      1 gpu004
#            3859583   hij-gpu   Matt_2  yu79deg  R      13:20      1 gpu004
#            3859638   hij-gpu   LP_171  yu79deg  R       2:29      1 gpu001
#            3859639   hij-gpu   LP_172  yu79deg  R       0:01      1 gpu002
#            3859640   hij-gpu   LP_173  yu79deg  R       0:01      1 gpu003

# %%
# !squeue --me # See that all simulations are indeed running.
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            3846796   hij-gpu jupyterl  yu79deg  R 2-06:05:31      1 gpu004
#            3859516   hij-gpu   LP_163  yu79deg  R       1:40      1 gpu004
#            3859517   hij-gpu   LP_164  yu79deg  R       1:40      1 gpu001

# %%
#################### EXTRACT SHADOW FACTOR FROM SIMULATION ###################
import darkfield.mmmUtils_v2 as mu

project_dir = '/home/yu79deg/darkfield_p5438/Aime'
yaml_tag = 'LP_124'  # Simulation name


pickle_file = os.path.join(project_dir, 'pickles', f'{yaml_tag}_res.pickle')
print(f"Loading: {pickle_file}")


res = mu.loadPickle(pickle_file) #loading the general parameters
params=res[1]

SF_13 = params['intensities']['roi'] / params['intensities']['TCC']
SF_75 = params['intensities']['roi2'] / params['intensities']['TCC']

print(SF_13,SF_75)
# Out:
# Loading: /home/yu79deg/darkfield_p5438/Aime/pickles/LP_124_res.pickle
# 3.265410688385406e-13 5.794672520111562e-12

# %%
################## PLOT THE EVOLUTION OF SHADOW FACTOR AS A FUNCTION OF A GIVEN SCANNED PARAMETER ###############

import os
import yaml
import matplotlib.pyplot as plt
import darkfield.mmmUtils_v2 as mu  # This must be available in your environment

# %matplotlib widget

# Setup paths
project_dir = '/home/yu79deg/darkfield_p5438/Aime'
yaml_dir = '/home/yu79deg/darkfield_p5438/yamls'
pickle_dir = os.path.join(project_dir, 'pickles')

# List of simulations (numbers only)
simulation_ids = np.arange(155,164)
simulations = [f'LP_{i}' for i in simulation_ids]

# Parameter config
ph_key = 'A1'               # The element key in YAML
scan_param_name = 'size'    # Parameter to scan
xaxis_label = 'smooth A1 size [µm]'  # Label for plot

# Data lists
scanned_values = []
sf_13_list = []
sf_75_list = []

# Loop through simulations
for sim in simulations:
    print(f"\nProcessing simulation: {sim}")

    # --- Load pickle file ---
    pickle_file = os.path.join(pickle_dir, f'{sim}_res.pickle')
    if not os.path.isfile(pickle_file):
        print(f"⚠️ Missing pickle file: {pickle_file}")
        continue

    res = mu.loadPickle(pickle_file)
    params = res[1]

    try:
        sf_13 = params['intensities']['roi'] / params['intensities']['TCC']
        sf_75 = params['intensities']['roi2'] / params['intensities']['TCC']
    except KeyError:
        print(f"⚠️ Missing intensity data in: {sim}")
        continue

    # --- Load YAML file ---
    yaml_file = os.path.join(yaml_dir, f'{sim}.yaml')
    if not os.path.isfile(yaml_file):
        print(f"⚠️ Missing YAML file: {yaml_file}")
        continue

    with open(yaml_file, 'r') as f:
        yaml_data = yaml.safe_load(f)

    # --- Extract parameter ---
    try:
        scan_value = yaml_data[ph_key][scan_param_name]
    except KeyError:
        print(f"⚠️ Parameter '{scan_param_name}' not found in element '{ph_key}' for {sim}")
        continue

    # Store data (convert to µm)
    scanned_values.append(scan_value * 1e6)
    sf_13_list.append(sf_13)
    sf_75_list.append(sf_75)

# --- Plotting ---
plt.figure(figsize=(5, 5))
plt.plot(scanned_values, sf_13_list, 'o-', label='SF_13')
plt.plot(scanned_values, sf_75_list, 's-', label='SF_75')
plt. yscale("log")
plt.xlabel(xaxis_label)
plt.ylabel("Shadow factor")
plt.title(f"Shadow factor vs {xaxis_label}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Processing simulation: LP_155
#
# Processing simulation: LP_156
#
# Processing simulation: LP_157
#
# Processing simulation: LP_158
#
# Processing simulation: LP_159
#
# Processing simulation: LP_160
#
# Processing simulation: LP_161
#
# Processing simulation: LP_162
#
# Processing simulation: LP_163
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
